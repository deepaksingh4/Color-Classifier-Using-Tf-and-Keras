# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten,  Dense
from keras import backend as k
import numpy as np
from keras.preprocessing import image
from matplotlib import pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
img_width, img_height = 28,28
train_data_dir = "/content/drive/My Drive/Colab Notebooks/images/train"
validation_data_dir = "/content/drive/My Drive/Colab Notebooks/images/validation"

nb_train_samples = 1500
nb_validation_samples = 100

epochs = 50
batch_size = 20


if k.image_data_format() == 'channels_first':
  input_shape =(3, img_width, img_height)
else:
  input_shape = (img_width, img_height,3)

# %%
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True
)

# %%
test_datagen = ImageDataGenerator(rescale= 1. / 255)

# %%
train_generator = train_datagen.flow_from_directory(
    
    train_data_dir,
    target_size = (img_width, img_height),
    batch_size = batch_size,
    class_mode = 'binary'
)
# Out:
# Found 3927 images belonging to 3 classes.

# %%
validation_generator = test_datagen.flow_from_directory(
    
    validation_data_dir,
    target_size = (img_width, img_height),
    batch_size = batch_size,
    class_mode = 'binary'
)
# Out:
# Found 159 images belonging to 3 classes.

# %%
###creating model


model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size =(2, 2)))

model.summary()

model.add(Conv2D(32, (3, 3) ))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size =(2, 2)))

model.add(Conv2D(64, (3, 3) ))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size =(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 26, 26, 32)        896
# _________________________________________________________________
# activation_6 (Activation)    (None, 26, 26, 32)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 13, 13, 32)        0
# ...
# Total params: 896
# Trainable params: 896
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 26, 26, 32)        896
# _________________________________________________________________
# activation_6 (Activation)    (None, 26, 26, 32)        0
# ...

# %%
model.compile( loss= 'binary_crossentropy',
              optimizer = 'rmsprop',
              metrics=['accuracy'])

model.fit_generator(
    train_generator,
    steps_per_epoch = nb_train_samples  //  batch_size,
    epochs = epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size  
)
# Out:
# Epoch 1/50
# 75/75 [==============================] - 4s 53ms/step - loss: -352758647029.7600 - accuracy: 0.4113 - val_loss: -62779019264.0000 - val_accuracy: 0.3100
# Epoch 2/50
# 75/75 [==============================] - 4s 51ms/step - loss: -390112516662.6133 - accuracy: 0.4233 - val_loss: -453965086720.0000 - val_accuracy: 0.2626
# Epoch 3/50
# 75/75 [==============================] - 4s 50ms/step - loss: -362845520363.6037 - accuracy: 0.4223 - val_loss: 67680915456.0000 - val_accuracy: 0.2900
# Epoch 4/50
# 75/75 [==============================] - 4s 58ms/step - loss: -405022476506.4533 - accuracy: 0.4333 - val_loss: -381996072960.0000 - val_accuracy: 0.4141
# Epoch 5/50
# 75/75 [==============================] - 4s 58ms/step - loss: -431437232749.0037 - accuracy: 0.4048 - val_loss: -190968872960.0000 - val_accuracy: 0.2121
# Epoch 6/50
# ...

# %%
 img_pred = image.load_img('/content/drive/My Drive/Colab Notebooks/images/validation/red/1093.png' , target_size = (28,28))
 img_pred = image.img_to_array(img_pred)
 img_pred = np.expand_dims(img_pred , axis = 0)

 rslt = model.predict(img_pred)
 print(rslt)


 if rslt[0][0] == 1:
   print('Red')
 else:
   print('wrong')
# Out:
# [[1.]]
# Red
